# %%
import streamlit as st
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
# %matplotlib inline

# %%
url = 'https://raw.githubusercontent.com/esnt/Data/refs/heads/main/Names/popular_names.csv'
df = pd.read_csv(url)

# %%
noi = 'Raefaerty'
name_df = df[df['name']==noi]

# %%
name_df
# Out:
# Empty DataFrame
# Columns: [name, sex, n, year]
# Index: []

# %%
sns.lineplot(x=name_df['year'], y=name_df['n'], hue=name_df['sex'])
plt.title(noi)
plt.xlabel('year')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %%
plt.show()

# %%
top10f = ['Mary', 'Patricia', 'Jennifer', 'Linda', 'Elizabeth', 'Barbara', 'Susan', 'Jessica', 'Karen', 'Sarah']
top10f_df = df[(df['name'].isin(top10f)) & (df['sex']=='F')]

# %%
top10f_df = top10f_df.drop('sex', axis=1)
top10f_df
# Out:
#              name      n  year
# 0            Mary  22848  1910
# 6       Elizabeth   5800  1910
# 39          Sarah   2173  1910
# 128       Barbara    612  1910
# 149         Susan    395  1910
# ...           ...    ...   ...
# 175796      Linda    321  2021
# 175801    Barbara    292  2021
# 175832      Karen    226  2021
# 175834      Susan    223  2021
# 175843   Patricia    209  2021
#
# [1111 rows x 3 columns]

# %%
sns.lineplot(x=top10f_df['year'], y=top10f_df['n'], hue=top10f_df['name'])
plt.show()
